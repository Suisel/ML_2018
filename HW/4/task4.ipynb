# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error


import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# Загружаем данные

# %%
data_file = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv")
data_file.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>month</th>
#       <th>day</th>
#       <th>FFMC</th>
#       <th>DMC</th>
#       <th>DC</th>
#       <th>ISI</th>
#       <th>temp</th>
#       <th>RH</th>
#       <th>wind</th>
#       <th>rain</th>
#       <th>area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>5</td>
#       <td>mar</td>
#       <td>fri</td>
#       <td>86.2</td>
#       <td>26.2</td>
#       <td>94.3</td>
#       <td>5.1</td>
#       <td>8.2</td>
#       <td>51</td>
#       <td>6.7</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
# ...

# %%
data = data_file.replace({'month' : {'jan' : 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}, 
                          'day' : {'mon': 1, 'tue': 2, 'wed': 3, 'thu': 4, 'fri': 5, 'sat': 6, 'sun': 7}})
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>month</th>
#       <th>day</th>
#       <th>FFMC</th>
#       <th>DMC</th>
#       <th>DC</th>
#       <th>ISI</th>
#       <th>temp</th>
#       <th>RH</th>
#       <th>wind</th>
#       <th>rain</th>
#       <th>area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>5</td>
#       <td>3</td>
#       <td>5</td>
#       <td>86.2</td>
#       <td>26.2</td>
#       <td>94.3</td>
#       <td>5.1</td>
#       <td>8.2</td>
#       <td>51</td>
#       <td>6.7</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
# ...

# %%
len(data)
# Out:
# 517

# %% [markdown]
# Выделяем тренировочное и тестовое множества

# %%
X = data.drop(['area'], axis=1)
Y = data['area']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=27)

# %% [markdown]
# svn с дефолтными параметрами

# %%
svm_def = SVR().fit(X_train, Y_train)

# %%
res_pred = svm_def.predict(X_test)

# %%
metrics.mean_squared_error(Y_test, res_pred)
# Out:
# 271.5680733649491

# %% [markdown]
# Посмотрим другие параметры

# %%
svr = GridSearchCV(SVR(kernel='rbf', gamma=0.1), cv=5, param_grid={"C": [1, 10, 100, 1000], "gamma": np.logspace(-2, 2, 5)})
svr.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [1, 10, 100, 1000], 'gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
svr.best_params_
# Out:
# {'C': 100, 'gamma': 100.0}

# %%
svm_par = SVR(C = 100.0, gamma = 100.0).fit(X_train, Y_train)
pred = svm_par.predict(X_test)

# %%
metrics.mean_squared_error(Y_test, pred)
# Out:
# 245.81486724779782
